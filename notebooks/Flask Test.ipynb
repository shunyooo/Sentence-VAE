# %%
import requests
import json
import urllib

# %%
keywords = 'セミナー 転職 エンジニア'
q = urllib.parse.urlencode({'keyword': keywords}, True)
url = f'http://127.0.0.1:8000/?{q}'

# %%
keywords
# Out:
# 'セミナー 転職 エンジニア'

# %%
import json
res = requests.get(url)
res_json = json.loads(res.content)

# %%
res_json
# Out:
# {'decoded': ['【急募】学生歓迎のお仕事探しなら',
#   '東京のフリーター、短期合格可能性を公開!パーソルグループの新tvcm「戦略発表篇」を公開!パーソルグループの新クリーム、誕生。',
#   '【経営者、必見!】エンジニア向け勉強会が無料で参加しています。',
#   '【急募】看護師、月<num>万、日勤のみ',
#   '自分の「強み」や「弱み」ってなんだろう?リクナビ<num>【spi性格検査】で自己理解を深めて就活準備に役立てよう!',
#   '【<num>卒向け無料】就職セミナー実施中!',
#   '【indeedでバイト探そう】インディードバイトなら求人サイトをまとめて検索できるからあなたにピッタリなバイトが見付かるかも!',
#   '劇団四季オーディション選考委員実績&合格者輩出&合格者輩出&合格者輩出&合格者輩出&合格者輩出&合格者輩出&合格者輩出&合格者輩出&移住フェア)',
#   '【急募】看護師、月<num>万、日勤のみ',
#   '【フリーランスエンジニア】募集中案件数<num>,<num>件以上!いま、大手・優良企業が採用を強化しています。',
#   '【<num>卒向け無料】就職セミナー実施中!',
#   '「手取<num>万は欲しい」岐阜県転職比較',
#   '【経営者、必見!】コスパ最強のオンライン勉強会「たまごアカデミー」を公開!',
#   '【<num>月入社を目指すならoffers】',
#   '【急募】看護師、月<num>万、日勤のみ',
#   '【急募】看護師さんの転職サイト',
#   '【急募】<num>月入社の求人が増加中',
#   '【急募】看護師、月給<num>万、賞与<num>ヶ月',
#   '【<org>、<org>、アサヒビールなど】未経験歓迎の求人<num>,<num>件以上!いま、大手・優良企業が採用を強化しています。',
#   '【急募】学生歓迎のお仕事探しなら',
#   '【急募】看護師、月<num>万、日勤のみ',
#   '【未経験ok】事務職転職サポート完全無料。',
#   '【経営者、必見!】エンジニア向けのための就活サイト「ビズリーチ」は、あなたのビジネス経験を活かして、はじめませんか?',
# ...
